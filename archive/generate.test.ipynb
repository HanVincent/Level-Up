# %%
#!/usr/bin/env python
# %load_ext autoreload
# %autoreload 2

from utils.preprocess import normalize
from utils.parser import nlp
from utils.auto_suggest import auto_suggest
from utils.grammar import iterate_all_patterns

# %%
def diff_after_before(text):
    before, after , count = [], [] , 0
    for token in text.split(' '):
        if token.startswith('{+'):
            after_word = token[2:-2].split('//')[0]
            after.append(after_word)
        elif token.startswith('[-'):
            if token.endswith('+}'):
                delete_tmp, insert_tmp = token[2:-2].split('-]{+')
                delete = delete_tmp.split('//')[0]
                insert = insert_tmp.split('//')[0]
                before.append(delete)
                after.append(insert)
            else:
                before_word = token[2:-2].split('//')[0]
                before.append(before_word)
        else:
            before.append(token)
            after.append(token)
    return ' '.join(after).replace('\u3000',' ')

# %%
test = []
for line in open('/atom/corpus/written/EFCAM/EFCAM.error.txt', 'r', encoding='utf8'):
    parse = nlp(diff_after_before(line))
    for i, tk in enumerate(parse):
        if tk.tag_.startswith('JJ'):
            test.append(' '.join([tk.text for tk in parse][:i+1]))
            break
            
    if len(test) > 400:
        break

# %%
tests = '''It has integrated functional
The bread is much larger
Now there are only 3 x 2 bedroom ones available
John encountered a strange
As he was approaching the corner at Elm and Fourth, he saw a young
Tim prepared to stop them after they vandalized the local
But suddenly, the young
Finally, they found the young
Now the couple has still not been caught which makes Leo scared
Firstly, you should only bring little
Hit the ball as many
To score a point, try to make the opposite
If you ask me what you want to do in the following
I would like to fluently use a foreign
Then, in my company, most
I think administration is better
The person in that position must work hard and is responsible
When I think of the journey, I feel it was very happy
I was surprised
Though we only stayed in USA for two days, it still left a deep
They come to a small
They do not have enough
Isabella and John are tired
I am willing
Grandfather is an old
You are addicted
It is my great
It would be very appreciated if you could spare a few
First of all, I would be a very good
I promise I will take every single
I promise we will have different
I will convince our principal to get more
I like music and digital
Later, we moved into the city to continue with my high
When I graduated from university, I found my first
I water the plants in the morning every day and then I take the dogs for a walk if it is not rainy
So studying English is the first
I need these extra
The viewing figures show that unemployed
You should make them most interesting
You must be more professional
It describes life where the singer lived before and his current
Although the lyrics are not happy
This is a very fashionable
When you wear them, you will detect yourself higher
Although you walk for a long
It is advisable
You have been late
The lunch was unbelievably fantastic
I was full
'If you allow me to give some suggestions, I think the music is not suitable
I am looking for a challenging
He has short
If we do not have many
If it is rainy
Please consider how much
Perhaps, you could bring home-made
Also, you could cook dinner at home or try a cheap
The most important
She wears long red shorts and a white
She has long
He is cool
He has fairly short
Mary and Jim are my Asian
I hope I could find a lover who would also love me deeply to establish a warmhearted
Dear Julia, I a, very angry
It gives me great
First, I will get a job in a chemical
Due to my promotion, I feel that my current
Today, the weather is rainy
It is going to be sunny
I could try to do special
At that time, my pretty
 Hi Anna, I have found an absolutely amazing
This job provides very good
I urge you to apply as soon as possible
Looking forward to your prompt
I am intelligent
Let me tell you why you should apply this exciting
I believe it is much higher
Furthermore, just as you expected, the benefits include full
I believe this is a good
The player with the most
They are cheaper
I have a small
I love every day , because it is a new
First , I will work hard for my recent
There is a tub filled with water and an empty
There is an empty
The member uses the bottle to transport the water to the empty
I work in a primary
I always work with children and it is very interesting
I work in a international
My job is too difficult
This afternoon is going to rain, so I will go to the museum and eat at one of the great
The Iyrics are beautiful
At that moment, I heard the loud
I called to police with a public
It is too far from a cosy
The captain was unfriendly
There is a good
After I finished high
I work for long
I am waiting for a long
Thousands of people are celebrating it together, and they will wear beautiful
It is going to be amazing
Maybe the clothes and shoes are sporting and comfortable
It is going to be great
He was a dangerous
Some of the valuable
All employees are required to wear natural'''.split('\n')

# %%
test = 'Then, in my company, most'
parse = nlp(test)
sugs = auto_suggest(parse, iterate_all_patterns(parse))

# %%
results = []
for test in tests:        
    parse = nlp(test)
    sugs = auto_suggest(parse, iterate_all_patterns(parse))
    sugs = filter(lambda sug: not sug['level'].startswith('A'), sugs['patterns'])
    ngrams = [sug['ngram'] + ' (' + sug['pattern'] + ')' for sug in sugs]

    if len(ngrams) < 3: continue 
    results.append((test, ngrams[:3]))
    
    
ws = open('testdata.txt', 'w', encoding='utf8')

start = '''var form = FormApp.create('English Level-Up');\n\n'''

template = ''

for i, (line, ngrams) in enumerate(results[:50]):
    print("="*20, file=ws)
    print(line, file=ws)
    print(file=ws)
    print('\n'.join(ngrams), file=ws)
    print('='*20, file=ws)
    print(file=ws)
    
    if i % 10 == 0:
        template += "form.addPageBreakItem().setTitle(" + str(i//10 + 1) + ");\n\n"
    options = ','.join(["'" + ngram + "'" for ngram in ngrams[:3]]) + ",'NONE'"
    template += "form.addCheckboxItem().setTitle('" + line + "').setChoiceValues([" + options + "]).showOtherOption(false).setRequired(true);\n\n"

print(start + template)
ws.close()
# Out:
# ['Please', 'consider', 'how', 'much']
# 32 3 5
# ['Please', 'consider', 'how', 'much']
# 32 3 5
# ['Please', 'consider', 'how', 'much']
# 115 3 5
# ['Please', 'consider', 'how', 'much']
# 115 3 5
# var form = FormApp.create('English Level-Up');
#
# form.addPageBreakItem().setTitle(1);
#
# form.addCheckboxItem().setTitle('It has integrated functional').setChoiceValues(['as functional as (as adj. as / so adj. that)','functional items such as (phrase-adj.)','purely functional terms (adv./adj. adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Now there are only 3 x 2 bedroom ones available').setChoiceValues(['data available to (phrase-adj.)','make themselves available (make n. adj.)','publicly available data (adv./adj. adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('John encountered a strange').setChoiceValues(['very strange feeling (adv./adj. adj. n.)','strange enough (adj. enough)','nothing strange (pronoun adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('As he was approaching the corner at Elm and Fourth, he saw a young').setChoiceValues(['young married couple (adv./adj. adj. n.)','young enough (adj. enough)','young players such as (phrase-adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Tim prepared to stop them after they vandalized the local').setChoiceValues(['local economic development (adv./adj. adj. n.)','much more local (degree-adv. (more/less) adj.)','someone local (pronoun adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('But suddenly, the young').setChoiceValues(['lovely young woman (adv./adj. adj. n.)','young enough (adj. enough)','young players such as (phrase-adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Finally, they found the young').setChoiceValues(['young enough (adj. enough)','handsome young man (adv./adj. adj. n.)','young players such as (phrase-adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Firstly, you should only bring little').setChoiceValues(['little enough (adj. enough)','something little (pronoun adj.)','little empirical evidence (adv./adj. adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Hit the ball as many').setChoiceValues(['many days (adv./adj. adj. n.)','something many (pronoun adj.)','many books written (phrase-adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('To score a point, try to make the opposite').setChoiceValues(['absolute opposite (degree-adj. n.)','the direction opposite to (phrase-adj.)','opposite central station (adv./adj. adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addPageBreakItem().setTitle(2);
#
# form.addCheckboxItem().setTitle('I would like to fluently use a foreign').setChoiceValues(['deputy foreign minister (adv./adj. adj. n.)','major foreign policy (degree-adj. n.)','anything foreign (pronoun adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Then, in my company, most').setChoiceValues(['by far the most effective (by far the (JJS|most JJ))','his most recent novel (det. (most) adj. n.)','most serious threat to ((most) adj. n. to)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('I think administration is better').setChoiceValues(['much better (much (more/less) adj.)','no better (no/not any (more/less) adj.)','so much better (much (more/less) adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('The person in that position must work hard and is responsible').setChoiceValues(['as responsible as (as adj. as / so adj. that)','executive responsible for (phrase-adj.)','someone responsible (pronoun adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('When I think of the journey, I feel it was very happy').setChoiceValues(['happy enough (adj. enough)','happy new year (adv./adj. adj. n.)','happy enough to let (adj. enough to v.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('I was surprised').setChoiceValues(['so surprised that (as adj. as / so adj. that)','even more surprised (degree-adv. (more/less) adj.)','no less surprised (no/not any (more/less) adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Though we only stayed in USA for two days, it still left a deep').setChoiceValues(['deep enough (adj. enough)','deep historical roots (adv./adj. adj. n.)','deep enough to allow (adj. enough to v.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('They come to a small').setChoiceValues(['very small fraction (adv./adj. adj. n.)','small enough (adj. enough)','small enough to allow (adj. enough to v.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('They do not have enough').setChoiceValues(['barely enough (adv. enough)','adequate enough (adj. enough)','barely enough time (adv./adj. adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Isabella and John are tired').setChoiceValues(['tired enough (adj. enough)','too tired to care (too adj. to v.)','even more tired (degree-adv. (more/less) adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addPageBreakItem().setTitle(3);
#
# form.addCheckboxItem().setTitle('I am willing').setChoiceValues(['much more willing (degree-adv. (more/less) adj.)','someone willing (pronoun adj.)','as willing as (as adj. as / so adj. that)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Grandfather is an old').setChoiceValues(['old enough (adj. enough)','old upright piano (adv./adj. adj. n.)','old enough to vote (adj. enough to v.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('It is my great').setChoiceValues(['great enough (adj. enough)','great physical strength (adv./adj. adj. n.)','nothing great (pronoun adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('It would be very appreciated if you could spare a few').setChoiceValues(['few extra minutes (adv./adj. adj. n.)','few enough (adj. enough)','quite a few (quite a adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('First of all, I would be a very good').setChoiceValues(['good enough (adj. enough)','good medical care (adv./adj. adj. n.)','good enough to keep (adj. enough to v.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('I promise I will take every single').setChoiceValues(['single foreign policy (adv./adj. adj. n.)','no one single (pronoun adj.)','single , consistent source (adj. , adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('I promise we will have different').setChoiceValues(['different people (adv./adj. adj. n.)','quite a different (quite a adj.)','different enough (adj. enough)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('I will convince our principal to get more').setChoiceValues(['more deeply ((more/less) adv.)','more and more (adj. and adj.)','even more intense (degree-adv. (more/less) adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Later, we moved into the city to continue with my high').setChoiceValues(['high enough (adj. enough)','moral high ground (adv./adj. adj. n.)','high enough to be (adj. enough to v.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('When I graduated from university, I found my first').setChoiceValues(['first few days (adv./adj. adj. n.)','first , second and third (adj. , adj. and adj.)','something first (pronoun adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addPageBreakItem().setTitle(4);
#
# form.addCheckboxItem().setTitle('So studying English is the first').setChoiceValues(['first few days (adv./adj. adj. n.)','entire first half (degree-adj. n.)','first , second and third (adj. , adj. and adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('I need these extra').setChoiceValues(['nothing extra (pronoun adj.)','little extra effort (adv./adj. adj. n.)','extra equipment , such as (phrase-adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('The viewing figures show that unemployed').setChoiceValues(['unemployed supplementary benefit (adv./adj. adj. n.)','people unemployed in (phrase-adj.)','total unemployed placings (degree-adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('You should make them most interesting').setChoiceValues(['interesting enough (adj. enough)','anyone interesting (pronoun adj.)','particularly interesting case (adv./adj. adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('You must be more professional').setChoiceValues(['highly professional career (adv./adj. adj. n.)','something professional (pronoun adj.)','as professional as (as adj. as / so adj. that)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('It describes life where the singer lived before and his current').setChoiceValues(['current prime minister (adv./adj. adj. n.)','total current expenditure (degree-adj. n.)','current issues such as (phrase-adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Although the lyrics are not happy').setChoiceValues(['happy enough (adj. enough)','very happy marriage (adv./adj. adj. n.)','quite a happy (quite a adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('This is a very fashionable').setChoiceValues(['so fashionable that (as adj. as / so adj. that)','expensive , fashionable clothes (adj. , adj. n.)','quite a fashionable (quite a adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('When you wear them, you will detect yourself higher').setChoiceValues(['much higher (much (more/less) adj.)','a bit higher (a bit (more/less) adj.)','so much higher (much (more/less) adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Although you walk for a long').setChoiceValues(['long enough (adj. enough)','long enough period (adv./adj. adj. n.)','quite a long (quite a adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addPageBreakItem().setTitle(5);
#
# form.addCheckboxItem().setTitle('You have been late').setChoiceValues(['as late as (as adj. as / so adj. that)','late last year (adv./adj. adj. n.)','late enough (adj. enough)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('The lunch was unbelievably fantastic').setChoiceValues(['so fantastic that (as adj. as / so adj. that)','too fantastic to be (too adj. to v.)','fantastic mr fox (adv./adj. adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('I was full').setChoiceValues(['so full that (as adj. as / so adj. that)','a warehouse full of (phrase-adj.)','much more full (degree-adv. (more/less) adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle(''If you allow me to give some suggestions, I think the music is not suitable').setChoiceValues(['much more suitable (degree-adv. (more/less) adj.)','make it suitable (make n. adj.)','as suitable as (as adj. as / so adj. that)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('I am looking for a challenging').setChoiceValues(['much more challenging (degree-adv. (more/less) adj.)','very challenging year (adv./adj. adj. n.)','quite a challenging (quite a adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('He has short').setChoiceValues(['short enough (adj. enough)','something short (pronoun adj.)','quite a short (quite a adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('If we do not have many').setChoiceValues(['too many times (adv./adj. adj. n.)','so many times that (as adj. as / so adj. that)','many , many miles (adj. , adj. n.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Please consider how much').setChoiceValues(['much lower (much (more/less) adj.)','much time (adv./adj. adj. n.)','much less likely (degree-adv. (more/less) adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('Also, you could cook dinner at home or try a cheap').setChoiceValues(['cheap enough (adj. enough)','cheap enough to be (adj. enough to v.)','something cheap (pronoun adj.)','NONE']).showOtherOption(false).setRequired(true);
#
# form.addCheckboxItem().setTitle('The most important').setChoiceValues(['important enough (adj. enough)','important natural resource (adv./adj. adj. n.)','important enough to justify (adj. enough to v.)','NONE']).showOtherOption(false).setRequired(true);
